# %%
import pandas as pd
import numpy as np

df=pd.read_csv(".\dogNames2.csv")

# %%
df
# Out:
#           Row_Labels  Count_AnimalName
# 0                  1                 1
# 1                  2                 2
# 2              40804                 1
# 3              90201                 1
# 4              90203                 1
# 5             102201                 1
# 6            3010271                 1
# 7              MARCH                 2
# 8              APRIL                51
# 9             AUGUST                14
# 10          DECEMBER                 4
# 11            SUNDAY                13
# 12            MONDAY                 4
# 13            FRIDAY                19
# 14               JAN                 1
# 15               JUN                 1
# 16           JANUARY                 1
# 17              JUNE                24
# 18              JULY                 9
# 19               MON                 2
# 20               MAY                13
# 21          NOVEMBER                 1
# 22           TUESDAY                 7
# ...

# %%
df[(df["Count_AnimalName"]<1000)&(df["Count_AnimalName"]>800)]
# Out:
#       Row_Labels  Count_AnimalName
# 2660     CHARLIE               856
# 3251        COCO               852
# 12368      ROCKY               823

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16220 entries, 0 to 16219
# Data columns (total 2 columns):
# Row_Labels          16217 non-null object
# Count_AnimalName    16220 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 253.5+ KB

# %%
df["Row_Labels"].tolist()
# Out:
# ['1',
#  '2',
#  '40804',
#  '90201',
#  '90203',
#  '102201',
#  '3010271',
#  'MARCH',
#  'APRIL',
#  'AUGUST',
#  'DECEMBER',
#  'SUNDAY',
#  'MONDAY',
#  'FRIDAY',
#  'JAN',
#  'JUN',
#  'JANUARY',
#  'JUNE',
#  'JULY',
#  'MON',
#  'MAY',
#  'NOVEMBER',
#  'TUESDAY',
#  'SEPTEMBER',
#  'WEDNESDAY',
#  'SUN',
#  '&QUOT;G&QUOT;',
#  '(LEELA)LILA',
#  '166Y',
#  '2CHAINZ',
#  '2J',
#  'A',
#  'A.',
#  'A.J',
#  'A.J.',
#  'AALIYAH',
#  'AALSKA',
#  'AARAV',
#  'AARON',
#  'AARYN',
#  'ABACA',
#  'ABAGAIL',
#  'ABBA',
#  'ABBEY',
#  'ABBEYROAD',
#  'ABBI',
#  'ABBIE',
#  'AB-BINGO',
#  'ABBOTT',
#  'ABBY',
#  'ABE',
#  'ABECROMBIE',
#  'ABEJA',
#  'ABEL',
#  'ABERCROMBIE',
#  'ABHAYA',
#  'ABI',
#  'ABIGAIL',
#  'ABIGALE',
#  'ABIGIAL',
#  'ABILENE',
#  'ABILGAIL',
#  'ABITA',
#  'ABLE',
#  'ABNER',
#  'ABRAHAM',
#  'ABREE',
#  'ABRIK',
#  'ABRIL',
#  'ABSOLUT',
#  'ABU',
#  'ABUELA',
#  'ABUJA',
#  'ABUR',
#  'ACCEL',
#  'ACCIDENTALLY',
#  'ACCURA',
#  'ACE',
#  'ACE-DAVE',
# ...

# %%
df[(df["Row_Labels"].str.len()>4)&(df["Count_AnimalName"]>400)]
# Out:
#       Row_Labels  Count_AnimalName
# 829       BAILEY               532
# 1156       BELLA              1195
# 2032       BUDDY               677
# 2660     CHARLIE               856
# 2913       CHLOE               465
# 3641       DAISY               649
# 8552       LUCKY               723
# 9766       MOLLY               519
# 11703   PRINCESS               603
# 12368      ROCKY               823
# 14466      TEDDY               485

# %%
pd.isnull(df)
# Out:
#        Row_Labels  Count_AnimalName
# 0           False             False
# 1           False             False
# 2           False             False
# 3           False             False
# 4           False             False
# 5           False             False
# 6           False             False
# 7           False             False
# 8           False             False
# 9           False             False
# 10          False             False
# 11          False             False
# 12          False             False
# 13          False             False
# 14          False             False
# 15          False             False
# 16          False             False
# 17          False             False
# 18          False             False
# 19          False             False
# 20          False             False
# 21          False             False
# 22          False             False
# 23          False             False
# 24          False             False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16220 entries, 0 to 16219
# Data columns (total 2 columns):
# Row_Labels          16217 non-null object
# Count_AnimalName    16220 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 253.5+ KB

# %%
%必须先确定是哪列
df[pd.isnull(df["Row_Labels"])]
# Out:
#       Row_Labels  Count_AnimalName
# 10143        NaN               101
# 10145        NaN                19
# 10576        NaN                 1

# %%
df.dropna(axis=0,how="any")
# Out:
#           Row_Labels  Count_AnimalName
# 0                  1                 1
# 1                  2                 2
# 2              40804                 1
# 3              90201                 1
# 4              90203                 1
# 5             102201                 1
# 6            3010271                 1
# 7              MARCH                 2
# 8              APRIL                51
# 9             AUGUST                14
# 10          DECEMBER                 4
# 11            SUNDAY                13
# 12            MONDAY                 4
# 13            FRIDAY                19
# 14               JAN                 1
# 15               JUN                 1
# 16           JANUARY                 1
# 17              JUNE                24
# 18              JULY                 9
# 19               MON                 2
# 20               MAY                13
# 21          NOVEMBER                 1
# 22           TUESDAY                 7
# ...

# %%
df
# Out:
#           Row_Labels  Count_AnimalName
# 0                  1                 1
# 1                  2                 2
# 2              40804                 1
# 3              90201                 1
# 4              90203                 1
# 5             102201                 1
# 6            3010271                 1
# 7              MARCH                 2
# 8              APRIL                51
# 9             AUGUST                14
# 10          DECEMBER                 4
# 11            SUNDAY                13
# 12            MONDAY                 4
# 13            FRIDAY                19
# 14               JAN                 1
# 15               JUN                 1
# 16           JANUARY                 1
# 17              JUNE                24
# 18              JULY                 9
# 19               MON                 2
# 20               MAY                13
# 21          NOVEMBER                 1
# 22           TUESDAY                 7
# ...

# %%
df.fillna(df.mean())
# Out:
#           Row_Labels  Count_AnimalName
# 0                  1                 1
# 1                  2                 2
# 2              40804                 1
# 3              90201                 1
# 4              90203                 1
# 5             102201                 1
# 6            3010271                 1
# 7              MARCH                 2
# 8              APRIL                51
# 9             AUGUST                14
# 10          DECEMBER                 4
# 11            SUNDAY                13
# 12            MONDAY                 4
# 13            FRIDAY                19
# 14               JAN                 1
# 15               JUN                 1
# 16           JANUARY                 1
# 17              JUNE                24
# 18              JULY                 9
# 19               MON                 2
# 20               MAY                13
# 21          NOVEMBER                 1
# 22           TUESDAY                 7
# ...
